# %%
def Summit_Spring():
    Jiquan_data = {
        '定位': '位於腋窩頂點，腋動脈搏動處。',
        '解剖': '在胸大肌的外下緣，深層為喙肱肌；外側為腋動脈；布有尺神經，正中神經，前臂內側皮神經及臂內側皮神經。腔內除大量的脂肪（內含有淋巴結及其相連的淋巴管）外，圍繞腋動脈有臂叢神經的三個束及其五條支配上肢肌的終支。而針經臂叢內側，可深達腋腔後壁肌肉之一大圓肌，該肌由肩胛下神經支配。',
        '主治': '心痛、胸悶、四肢不收、肩周炎、腋下瘰癧（頸淋巴結核）、腋臭、悲愁不樂、咽干、煩渴、乾嘔、目黃、臂肩不舉、肘臂攣痛、冠心病、心絞痛、心包炎、腦血管病後遺症、 肋間神經痛、癔病、乳汁分泌不足。彈撥本穴可預防冠心病，肺心病。',
        '配伍': '心痛乾嘔煩滿：配俠白穴（《針灸資生經》）。腋窩痛：配日月穴、肩貞穴、少海穴、內關穴、陽輔穴、丘墟穴（《針灸學手冊》）。四肢不收：配日月穴、脾俞穴（《針灸資生經》）。咽乾咽喉腫痛：配太淵穴、偏歷穴、太沖穴、天突穴（出處同上）。心悸、冠心病：配神門穴、內關穴、心俞穴，有寧心安神的作用。肘臂冷痛：配俠白，有通經活絡的作用。',
        '刺灸法': '刺法：避開腋動脈，直刺0.3～0.5寸，整個腋窩酸脹，有麻電感向前臂、指端放散，或上肢抽動，以3次為度。灸法：艾炷灸或溫針灸3～5壯，艾條灸5～10分鐘。　　'
    }
    return Jiquan_data

def Penetrating_the_Interior():
    Tongli_data = {
        '定位': '在前臂掌側，當尺側腕屈肌腱的橈側緣，腕橫紋上１寸。',
        '解剖': ' 在尺側腕屈肌與指淺屈肌之間，深層為指深屈肌；有尺動脈通過；布有前臂內側皮神經，尺側為尺神經。',
        '主治': ' 心悸，怔仲，暴喑，舌強不語，腕臂痛。',
        '配伍': '配廉泉、啞門治不語。',
        '刺灸法': '直刺0.3～0.5寸。'
    }
    return Tongli_data
def Spirit_Gate():
    Shenmen_data = {
        '定位': '在腕部，腕掌側橫紋尺側端，尺側腕屈肌腱的橈側凹陷處。',
        '解剖': '在尺側腕屈肌與指淺屈肌之間，深層為指深屈肌；有尺動脈通過；布有前臂內側皮神經，尺側為尺神經。',
        '主治': '心病，心煩，驚悸，怔仲，健忘，失眠，癲狂癇，胸脅痛。',
        '配伍': '配內關、心俞治心痛；配內關、三陽交治健忘、失眠。',
        '刺灸法': '直刺0.3～0.5寸。'
    }
    return Shenmen_data
def Lesse_Rushing():
  Shaochong_data = {
        '定位': '小指末節撓側，距指甲角0.1寸處。別名經始。',
        '解剖': '有指掌側固有動、靜脈所形成的動、靜脈網；布有指掌側固有神經。',
        '主治': '心悸，心痛，胸脅痛，癲狂，熱病，昏迷，手攣臂痛。',
        '配伍': '配太沖、中沖、大椎治熱病、昏迷。',
        '刺灸法': ' 淺刺0.1寸或點刺出血。'
    }
  return Shaochong_data

def Heart_Meridian_of_Hand_shaoyin():
    acupoints_info = {
        '極泉穴': Summit_Spring(),
        '通里穴': Penetrating_the_Interior(),
        '神門穴': Spirit_Gate(),
        '少沖穴': Lesse_Rushing(),
        # ... 其他穴位
    }
    return acupoints_info

def get_acupoint_info(acupoint_name, info_category=None):
    acupoints_info = Heart_Meridian_of_Hand_shaoyin()
    acupoint_data = acupoints_info.get(acupoint_name, None)
    if acupoint_data is None:
        return "未找到指定的穴位信息。"

    if info_category:
        return acupoint_data.get(info_category, "未找到指定類別的信息。")

    return acupoint_data


def query_acupoint():
    while True:
        print("\n--- 查詢系統 ---")
        acupoint_name = input("請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:\n(極泉穴、通里穴、神門穴、少沖穴):")
        if acupoint_name == "退出":
            print("\n--- 已退出查詢 ---")
            print("感謝使用本系統，祝你好運owo")
            break

        acupoint_info = get_acupoint_info(acupoint_name)
        if "未找到" in acupoint_info:
            print(f"\n{acupoint_info}\n")
            continue

        while True:
            print(f"\n找到穴位：{acupoint_name}")
            print("可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法")
            info_category = input("請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:")

            if info_category == "返回":
                print("\n返回上一層...\n")
                break
            elif info_category == "全部":
                print(f"\n{acupoint_name} - 全部信息:")
                for category, detail in acupoint_info.items():
                    print(f"{category}: {detail}")
                print()  # 為了排版整潔owo
            elif info_category in ["定位", "解剖", "主治", "配伍", "刺灸法"]:
                category_info = get_acupoint_info(acupoint_name, info_category)
                print(f"\n{acupoint_name} - {info_category}:\n{category_info}\n")
            else:
                print("\n輸入的信息類別不正確，請重新輸入。\n")

            # 再次查詢或返回
            while True:
                next_action = input("輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：")
                if next_action in ["再查詢", "返回"]:
                    break
                else:
                    print("請輸入有效的指令（'再查詢' 或 '返回'）。")
            if next_action == "返回":
                print("\n返回穴位選擇...")
                break
# 啟動查詢
query_acupoint()
# Out:
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (極泉穴、通里穴、神門穴、少沖穴):少沖穴
#
# 找到穴位：少沖穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:定位
#
# 少沖穴 - 定位:
# 小指末節撓側，距指甲角0.1寸處。別名經始。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：再查詢
#
# 找到穴位：少沖穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:解剖
#
# 少沖穴 - 解剖:
# 有指掌側固有動、靜脈所形成的動、靜脈網；布有指掌側固有神經。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：主治
# 請輸入有效的指令（'再查詢' 或 '返回'）。
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：再查詢
#
# 找到穴位：少沖穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:主治
#
# 少沖穴 - 主治:
# 心悸，心痛，胸脅痛，癲狂，熱病，昏迷，手攣臂痛。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：再查詢
#
# 找到穴位：少沖穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:配伍
#
# 少沖穴 - 配伍:
# 配太沖、中沖、大椎治熱病、昏迷。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：再查詢
#
# 找到穴位：少沖穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:刺灸法
#
# 少沖穴 - 刺灸法:
#  淺刺0.1寸或點刺出血。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：返回
#
# 返回穴位選擇...
#
# --- 查詢系統 ---
# ...
